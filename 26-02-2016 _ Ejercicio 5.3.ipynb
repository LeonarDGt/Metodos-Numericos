# %%
import math
import matplotlib.pyplot as L
# %matplotlib inline

c=4.5
b=2.5
a=-0.5
cx1=0
cx2=0
fc=0
xrb=0
x1b=0.5
x2b=1  
x1=0.5
x2=1
xrf=0
i=0
fx=0
ft=0
x=[]
y=[]
z=[]
k=[]
l=[1,0,-1]
fu=0
Ev=0
Ev1=0
Et=0
Ea=0
e2=0
e1=0
n=10
l=[1,0,-1]

  
print("Falsa Posicion\n");
print ("{0:15}  {1:15}  {2:15}  {3:15}   {4:15}  {5:15}".format("    Iteracion","         X1","         X2","         Xr","         Ea","         Et"));
while True:
    e2=xrf
    fc=0.7*x1**5-8*x1**4+44*x1**3-90*x1**2+82*x1-25
    fu=0.7*x2**5-8*x2**4+44*x2**3-90*x2**2+82*x2-25   
    xrf=x2-(fu*(x1-x2)/(fc-fu))
    ft=fc*fu
    e1=xrf
    #print("Error verdadero");
    Ev=0.57940934
    Et=(Ev/xrf)*100
    #print("Error aproximado");
    if e2==0:
        Ea=0
    else:
        Ea=((xrf-e2)/xrf)*100
    if ft>0:
        print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1,round(x2,4),round(xrf,4),round(Ea,4),round(Et,4)));
        x1=xrf
    elif ft<0:
        print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1,round(x2,4),round(xrf,4),round(Ea,4),round(Et,4)));
        x2=xrf 
    elif ft==0:
        
        print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1,round(x2,4),round(xrf,4),round(Ea,4),round(Et,4)));
        break
#print(xr);
    if i>4:
        break
    k.append(i)
    z.append(fu)
    i=i+1 


print("Biseccion\n");
print ("{0:15}  {1:15}  {2:15}  {3:15}   {4:15}  {5:15}".format("    Iteracion","         X1","         X2","         Xr","         Ea","         Et"));

i=0
e2=0
e1=0
Et=0
Ea=0
while True:
        e2=e1
        xrb=(x1b+x2b)/2
        fc=0.7*x1b**5-8*x1b**4+44*x1b**3-90*x1b**2+82*x1b-25
        fx=0.7*xrb**5-8*xrb**4+44*xrb**3-90*xrb**2+82*xrb-25
        fu=0.7*i**5-8*i**4+44*i**3-90*i**2+82*i-25
        ft=fc*fx
        e1=xrb
        #print("Error verdadero");
        Ev=0.57940934 
        Et=(Ev/xrb)*100
        #print("Error aproximado");
        if e2==0:
            Ea=0
        else:
            Ea=((xrb-e2)/xrb)*100
            
        if ft>0:
            print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1,round(x2,4),round(xrb,4),round(Ea,4),round(Et,4)));
            x1b=xrb
        elif ft<0:
            print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1,round(x2,4),round(xrb,4),round(Ea,4),round(Et,4)));
            x2b=xrb
        elif ft==0:
            print ("{0:15} | {1:15} | {2:15} | {3:15}  | {4:15} | {5:15} ".format((i),x1,round(x2,4),round(xrb,4),round(Ea,4),round(Et,4)));
            break
        #print(xr);
        if i>4:
            break
        
        x.append(i)
        y.append(fu)
        i=i+1
    
xl=[Ev,Ev,Ev]

L.plot(k,z,'k',linewidth=2,label='Falsa pocicion')
L.plot(xl,l,'k',linewidth=2,label='Raiz 1(xr)')
L.hold(True)
L.grid(True)
L.plot(x,y,'r',linewidth=2,label='Biceccion')
L.legend(loc = 2)
L.show()
# Out:
# Falsa Posicion
#
#     Iteracion             X1               X2               Xr                Ea               Et
#               0 |             0.5 |               1 |          0.6427  |               0 |         90.1485
#               1 |             0.5 |          0.6427 |           0.588  |         -9.3043 |         98.5361
#               2 |             0.5 |           0.588 |          0.5805  |         -1.2885 |         99.8058
#               3 |             0.5 |          0.5805 |          0.5796  |         -0.1692 |         99.9747
#               4 |             0.5 |          0.5796 |          0.5794  |         -0.0221 |         99.9967
#               5 |             0.5 |          0.5794 |          0.5794  |         -0.0029 |         99.9996
# Biseccion
#
#     Iteracion             X1               X2               Xr                Ea               Et
#               0 |             0.5 |          0.5794 |            0.75  |               0 |         77.2546
#               1 |             0.5 |          0.5794 |           0.625  |           -20.0 |         92.7055
#               2 |             0.5 |          0.5794 |          0.5625  |        -11.1111 |        103.0061
#               3 |             0.5 |          0.5794 |          0.5938  |          5.2632 |         97.5847
#               4 |             0.5 |          0.5794 |          0.5781  |         -2.7027 |        100.2222
#               5 |             0.5 |          0.5794 |          0.5859  |          1.3333 |         98.8859
